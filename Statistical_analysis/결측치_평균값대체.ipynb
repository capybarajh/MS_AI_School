# %% [markdown]
# # 시계열 데이터에서 결측치를 평균값으로 대체한 후 시각화 실습

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
# 시계열 데이터 생성
np.random.seed(42)
dates = pd.date_range(start='2023-01-01', periods=1000, freq='D')
values = np.random.randn(1000)

# 데이터 프레임 생성
data = pd.DataFrame({
    'Date' : dates,
    'Value' : values
})

print(data)

# 결측치 생성 
data.loc[50:100, 'Value'] = np.nan
# print(data.loc[50:100])
# Out:
#           Date     Value
# 0   2023-01-01  0.496714
# 1   2023-01-02 -0.138264
# 2   2023-01-03  0.647689
# 3   2023-01-04  1.523030
# 4   2023-01-05 -0.234153
# ..         ...       ...
# 995 2025-09-22 -0.281100
# 996 2025-09-23  1.797687
# 997 2025-09-24  0.640843
# 998 2025-09-25 -0.571179
# 999 2025-09-26  0.572583
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### 평균값으로 대처한 후 시각화

# %%
mean_value = data['Value'].mean()
print(mean_value)
data['Value_filled'] = data['Value'].fillna(mean_value)
print(data.loc[50:100])

# 시계열 데이터 시각화
plt.plot(data['Date'], data['Value'], 'o-', label='Original')
plt.plot(data['Date'], data['Value_filled'], 'x-', label='Mean Imputation')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Mean Imputation')
plt.legend()
plt.show()
# Out:
# 0.0209255880305356
#           Date  Value  Value_filled
# 50  2023-02-20    NaN      0.020926
# 51  2023-02-21    NaN      0.020926
# 52  2023-02-22    NaN      0.020926
# 53  2023-02-23    NaN      0.020926
# 54  2023-02-24    NaN      0.020926
# 55  2023-02-25    NaN      0.020926
# 56  2023-02-26    NaN      0.020926
# 57  2023-02-27    NaN      0.020926
# 58  2023-02-28    NaN      0.020926
# 59  2023-03-01    NaN      0.020926
# 60  2023-03-02    NaN      0.020926
# 61  2023-03-03    NaN      0.020926
# 62  2023-03-04    NaN      0.020926
# 63  2023-03-05    NaN      0.020926
# 64  2023-03-06    NaN      0.020926
# 65  2023-03-07    NaN      0.020926
# 66  2023-03-08    NaN      0.020926
# 67  2023-03-09    NaN      0.020926
# 68  2023-03-10    NaN      0.020926
# 69  2023-03-11    NaN      0.020926
# 70  2023-03-12    NaN      0.020926
# 71  2023-03-13    NaN      0.020926
# 72  2023-03-14    NaN      0.020926
# 73  2023-03-15    NaN      0.020926
# 74  2023-03-16    NaN      0.020926
# 75  2023-03-17    NaN      0.020926
# 76  2023-03-18    NaN      0.020926
# 77  2023-03-19    NaN      0.020926
# 78  2023-03-20    NaN      0.020926
# 79  2023-03-21    NaN      0.020926
# 80  2023-03-22    NaN      0.020926
# 81  2023-03-23    NaN      0.020926
# 82  2023-03-24    NaN      0.020926
# 83  2023-03-25    NaN      0.020926
# 84  2023-03-26    NaN      0.020926
# 85  2023-03-27    NaN      0.020926
# 86  2023-03-28    NaN      0.020926
# 87  2023-03-29    NaN      0.020926
# 88  2023-03-30    NaN      0.020926
# 89  2023-03-31    NaN      0.020926
# 90  2023-04-01    NaN      0.020926
# 91  2023-04-02    NaN      0.020926
# 92  2023-04-03    NaN      0.020926
# 93  2023-04-04    NaN      0.020926
# 94  2023-04-05    NaN      0.020926
# 95  2023-04-06    NaN      0.020926
# 96  2023-04-07    NaN      0.020926
# 97  2023-04-08    NaN      0.020926
# 98  2023-04-09    NaN      0.020926
# 99  2023-04-10    NaN      0.020926
# 100 2023-04-11    NaN      0.020926
