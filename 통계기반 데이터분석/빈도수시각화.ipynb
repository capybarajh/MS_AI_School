# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 생성
data = np.random.randint(1, 7, size=100)
print(data)

unique, counts = np.unique(data, return_counts=True)
print(unique)

print(counts)
# Out:
# [6 4 2 5 3 1 5 6 4 4 2 5 4 5 6 2 5 6 3 3 3 1 1 3 6 1 5 1 6 3 1 4 4 1 3 2 3
#  3 1 2 3 3 1 1 5 4 3 2 5 2 2 6 4 4 1 2 5 4 4 6 3 1 5 2 1 4 5 1 2 3 3 6 6 6
#  6 3 1 2 1 1 3 4 2 1 2 3 4 6 5 4 2 1 2 1 3 3 2 1 3 4]
# [1 2 3 4 5 6]
# [21 17 21 16 12 13]

# %%
# 막대 그래프 시각화
fig, ax = plt.subplots()
ax.bar(unique, counts)
ax.set_xlabel('Value')
ax.set_ylabel('Frequency')
ax.set_title('Frequency Distribution')
plt.show()
